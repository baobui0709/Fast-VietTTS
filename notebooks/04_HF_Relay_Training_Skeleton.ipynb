# %% [markdown]
# # HF Relay Training — Skeleton
# Notebook khung cho phase model-level. Chưa train student thật.

# %%
# !pip install -q huggingface_hub
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# Mục tiêu: dùng Hugging Face làm kho dataset/token shards/checkpoint để train relay qua nhiều phiên Colab hợp lệ.

# %%
HF_DATASET_REPO = 'username/fast-viettts-token-dataset'
HF_MODEL_REPO = 'username/fast-viettts-student'
print(HF_DATASET_REPO, HF_MODEL_REPO)

# %% [markdown]
# Các script chuẩn bị dataset/token/training sẽ được tạo ở phase sau: Agent 20A.
